# %%
# Color Threshold, Green Screen
# Import Resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %%
# Read in the image
image = cv2.imread('images/car_green_screen.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)
# Out:
# Image dimensions: (450, 660, 3)

# %%
# Display the image
plt.imshow(image)
plt.show()

# %%
# Define the color Threshold
## TODO: Define our color selection boundaries in RGB values
lower_green = np.array([0,160,0])
upper_green = np.array([255,255,255])

# %%
# Create a mask
# Plot the masked area

mask = cv2.inRange(image, lower_green, upper_green)
plt.imshow(mask,cmap='gray')
plt.show()

# %%
# mask the image to let the car show through


#masked_image = np.copy(image)
#masked_image[mask!=0]=[0,0,0]


#plt.imshow(masked_image)
#plt.show()








# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image,cmap='gray')
plt.show()

# %%
# Mask and add a background image 

# laod a background image ( and convert it to RGB if it is read by OpenCV)

# %%
background_image = cv2.imread("images/sky2.jpg")
background_image = cv2.cvtColor(background_image,cv2.COLOR_BGR2RGB)
cropped_background = background_image[0:450,0:660]

plt.imshow(cropped_background)
plt.show()

# %%
# Load in a background image, and convert it to RGB 
background_image = mpimg.imread('images/sky2.jpg')

## TODO: Crop it or resize the background to be the right size (450x660)
crop_image = background_image[0:450,0:660]

## TODO: Mask the cropped background so that the car area is blocked
# Hint mask the opposite area of the previous image
crop_image[mask==0] = [0,0,0]

## TODO: Display the background and make sure 
plt.imshow(crop_image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-4d62e01310f8> in <module>
#       7 ## TODO: Mask the cropped background so that the car area is blocked
#       8 # Hint mask the opposite area of the previous image
# ----> 9 crop_image[mask==0] = [0,0,0]
#      10
#      11 ## TODO: Display the background and make sure
#
# ValueError: assignment destination is read-only

# %% [markdown]
# ### Create a complete image

# %%
## TODO: Add the two images together to create a complete image!
# complete_image = masked_image + crop_background

# %%
complete_image = masked_image+crop_image
plt.imshow(complete_image)
